# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
#  knn clasification from binary implementation
class KNNClassifier:
    def __init__(self,k =3):
        self.k = k
    def euclidean_dist(self,X1,X2):
       return np.sqrt(np.sum((X1-X2)**2))

    def fit(self,X,y):
        self.X_train = X
        self.y_train = y

    def _predict(self,X):
        distances =  [self.euclidean_dist(X,X_train) for X_train in self.X_train]
        Knn_indices =np.argsort(distances)[:self.k]

        knn_classes = [self.y_train[i] for i in Knn_indices]

        majority_classes = np.argmax(np.bincount(knn_classes))
        return majority_classes

        
    def predict(self,X):
     y_pred = [self._predict(x) for x in X]
     return np.array( y_pred)

# %%
#  binncount use hoga too count repeated values 
KNN_classes = [0,0,0,0,1,1,3,3,5]
np.argmax(np.bincount(KNN_classes))
# sbse max values ajayegi isme
# Out:
# np.int64(0)

# %%
# X2= np.array([3,4])
# np.sqrt(np.sum((X1-X2)**2))

distances = [5,4,6,7,0,1]
np.argsort(distances)[:3]
#  index ke hisab se sort krega
# Out:
# array([4, 5, 1])

# %%
#  data
X_train= np.array([
    [1,2],
    [2,3],
    [3,3],
    [6,5],
    [7,7]
    
    ])
y_train = np.array([0,0,0,1,1])
X_test = np.array([
    [2,2],
    [6,6]
])
model = KNNClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [0 1]

# %%
#  visualize 
X_train_df= pd.DataFrame(X_train,columns = ["X1","X2"])
X_train_df["label"] = y_train
sns.scatterplot(
    data = X_train_df,
    x = "X1",
    y = "X2",
    hue = "label"

)
X_test = pd.DataFrame(X_test,columns = ["X1","X2"])
sns.scatterplot(
    data = X_test,
    x = "X1",
    y = "X2",
    color = "black",
    marker = "X",
    label = "Test Points"
)
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
X_train_df
# Out:
#    X1  X2  label
# 0   1   2      0
# 1   2   3      0
# 2   3   3      0
# 3   6   5      1
# 4   7   7      1
